# %%
from Dataloader import DataLoader
import numpy as np

# %%
B,T,split = 8,16,""


dl = DataLoader(B,T,split)

# %%
x,y = dl.next_batch()

# %%
x.shape,y.shape

# %%
tab = np.load("data/tokens/tokens_0.npy")

# %%
tab.shape

# %%
tab[:B*T]

# %%
x

# %%
y

# %%
for i in range(10_000_000):
    print(i)
    x,y = dl.next_batch()
