# %%
from utils import get_tokenizer,get_tokens_paths
from config import *
import os

# %%
tokenizer = get_tokenizer()
text = """
je suis la 
puis la 
puis la 
puis ici
"""

# %%
encode = tokenizer.encode(text)

# %%
print(encode.tokens)
# Out:
# ['je', 'suis', 'la', 'puis', 'la', 'puis', 'la', 'puis', 'ici']

# %%
l = get_tokens_paths()

# %%
l
# Out:
# ['tokens_0.npy',
#  'tokens_1.npy',
#  'tokens_10.npy',
#  'tokens_11.npy',
#  'tokens_12.npy',
#  'tokens_13.npy',
#  'tokens_14.npy',
#  'tokens_15.npy',
#  'tokens_16.npy',
#  'tokens_17.npy',
#  'tokens_18.npy',
#  'tokens_19.npy',
#  'tokens_2.npy',
#  'tokens_20.npy',
#  'tokens_21.npy',
#  'tokens_22.npy',
#  'tokens_23.npy',
#  'tokens_24.npy',
#  'tokens_3.npy',
#  'tokens_4.npy',
#  'tokens_5.npy',
#  'tokens_6.npy',
#  'tokens_7.npy',
#  'tokens_8.npy',
#  'tokens_9.npy']
