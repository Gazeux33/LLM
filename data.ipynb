# %%
from utils import *
from config import *
import os
# Out:
# using device: mps

# %%
tokenizer = get_tokenizer()
text = """
je suis la 
puis la 
puis la 
puis ici
"""

# %%
encode = tokenizer.encode(text)

# %%
print(encode.tokens)
# Out:
# ['je', 'suis', 'la', 'puis', 'la', 'puis', 'la', 'puis', 'ici']

# %%
l = get_tokens_paths()

# %%
l
# Out:
# ['data/tokens/tokens_0.npy',
#  'data/tokens/tokens_1.npy',
#  'data/tokens/tokens_10.npy',
#  'data/tokens/tokens_11.npy',
#  'data/tokens/tokens_12.npy',
#  'data/tokens/tokens_13.npy',
#  'data/tokens/tokens_14.npy',
#  'data/tokens/tokens_15.npy',
#  'data/tokens/tokens_16.npy',
#  'data/tokens/tokens_17.npy',
#  'data/tokens/tokens_18.npy',
#  'data/tokens/tokens_19.npy',
#  'data/tokens/tokens_2.npy',
#  'data/tokens/tokens_20.npy',
#  'data/tokens/tokens_21.npy',
#  'data/tokens/tokens_22.npy',
#  'data/tokens/tokens_23.npy',
#  'data/tokens/tokens_24.npy',
#  'data/tokens/tokens_3.npy',
#  'data/tokens/tokens_4.npy',
#  'data/tokens/tokens_5.npy',
#  'data/tokens/tokens_6.npy',
#  'data/tokens/tokens_7.npy',
#  'data/tokens/tokens_8.npy',
#  'data/tokens/tokens_9.npy']

# %%
data = get_vocab_size()

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['version', 'truncation', 'padding', 'added_tokens', 'normalizer', 'pre_tokenizer', 'post_processor', 'decoder', 'model'])

# %%
type(data["model"]["vocab"])
# Out:
# dict
