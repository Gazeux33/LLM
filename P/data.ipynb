# %%
import torch

# %%
torch.backends.mps.is_available()
# Out:
# True

# %%
hasattr(torch.backends,"mps")
# Out:
# True

# %%
embd = 2
B,T  = 2,4

# %%
x = torch.randn(B,T,embd,dtype=torch.long)
y = torch.randn(B,T)

x,y
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 x = torch.randn(B,T,embd,dtype=torch.long)
#       2 y = torch.randn(B,T)
#       4 x,y
#
# RuntimeError: "normal_kernel_cpu" not implemented for 'Long'

# %%
loss = torch.nn.functional.cross_entropy(x.view(-1,x.size(-1)),y.view(-1))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 loss = torch.nn.functional.cross_entropy(x.view(-1,x.size(-1)),y.view(-1))
#
# File ~/anaconda3/envs/LLM/lib/python3.11/site-packages/torch/nn/functional.py:3086, in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3084 if size_average is not None or reduce is not None:
#    3085     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3086 return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
#
# RuntimeError: expected scalar type Long but found Float
